# %%
import cv2
import numpy as np
from cv2 import VideoWriter, VideoWriter_fourcc
from pdb import set_trace
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from pdb import set_trace

# %%
def GenerateData():
    width = 64
    height = 64
    seconds = 10
    radius = 1
    FPS=24
    paint_h = int(height/2)
    VideoData = []
    fourcc = VideoWriter_fourcc(*'MP42')
    video = VideoWriter('./data/circle_noise1.avi', fourcc, float(FPS), (width, height))

    #Design the testing data
    for paint_x in range(-radius, width+radius+1, 1):
        frame = 255*np.ones((height, width), dtype=np.uint8)
        cv2.circle(frame, (paint_x, paint_h), radius, (0, 0, 0), -1)
        video.write(cv2.cvtColor(frame,cv2.COLOR_GRAY2BGR))
        VideoData.append(frame)
        
    video.release()

    VideoTrain = np.stack(VideoData, axis=0)

#     for paint_x in range(-radius, width+radius+1, 2):
#         frame = 255*np.ones( 
#                        (height, width), 
#                                   dtype=np.double)
#         cv2.circle(frame, (paint_x, paint_h), radius, (0, 0), -1)
#         VideoData.append(frame)

#     VideoTest = np.stack(VideoData, axis=0)

    return torch.tensor(VideoTrain,dtype=torch.float)

# %%
VideoTrain = GenerateData()
index = 50
print(VideoTrain.shape[0])
VideoIn = VideoTrain[:-1]
VideoOut = VideoTrain[1:34]
print(VideoIn.shape[0])
print(VideoOut.shape[0])
# Out:
# 67
# 66
# 33

# %%
#Define the architecture for the RNN
from pdb import set_trace
class RNN(nn.Module):
    def __init__(self, dt, height, width, frames):
        super(RNN, self).__init__()
        self.dt = dt
        self.height = height
        self.width = width
        self.W = nn.Parameter(255*torch.ones(frames, height, width))
        self.b = nn.Parameter(255*torch.ones(frames, height, width))
        self.frames = frames
        
    def forward(self,X):
        # Make the dynamics here
        # Extract the image of the object
        # Define the parameters for the new position
        # Predict the object there
        frames = X.shape[0]//2
        output = []
        for i in range(frames):
            #Extract the indices of the object
            param = torch.matmul(self.W[i], X[i]) + self.b[i]
#             newframe = X[i] + self.dt*param
            genframe = param + self.dt*param
            output.append(genframe)
           
        return torch.stack(output, axis=0)

# %%
rnn = RNN(1/24, 64,64, 67)
optimizer = torch.optim.Adam(rnn.parameters(), lr=1e-1)
n_epochs = 10000
delay = 5
lossfn = nn.MSELoss()

# %%
for i in range(n_epochs):
    output = rnn(VideoIn)
    loss = lossfn(output, VideoOut)
    if (i%delay == 0):
        print(loss.item())
    loss.backward()
    optimizer.step()
# Out:
# 18748593405952.0
# 18677302820864.0
# 18604089147392.0
# 18526502912000.0
# 18444506365952.0
# 18358523133952.0
# 18268905537536.0
# 18176190447616.0
# 18080671465472.0
# 17982914822144.0
# 17883218313216.0
# 17781871345664.0
# 17679217852416.0
# 17575490617344.0
# 17470844829696.0
# 17365498593280.0
# 17259557814272.0
# 17153186070528.0
# 17046469345280.0
# 16939510398976.0
# 16832314474496.0
# 16725059829760.0
# 16617700327424.0
# 16510343970816.0
# 16403065208832.0
# 16295794835456.0
# 16188669165568.0
# 16081614798848.0
# 15974803701760.0
# 15868116336640.0
# 15761659658240.0
# 15655421083648.0
# 15549420535808.0
# 15443669549056.0
# 15338218455040.0
# 17949908992.0
# 15320008704.0
# 12901016576.0
# 10692197376.0
# 8692808704.0
# 6902135296.0
# 5319483904.0
# 3944120320.0
# 2775336960.0
# 1812423040.0
# 1054653120.0
# 501316448.0
# 151699168.0
# 5084868.0
# 60760136.0
# 318010784.0
# 776124032.0
# 1434383232.0
# 2292075008.0
# 3348490496.0
# 4602911232.0
# 6054633472.0
# 7702944256.0
# 9547102208.0
# 11586440192.0
# 13820219392.0
# 16247688192.0
# 18868234240.0
# 21681063936.0
# 24685461504.0
# 27880814592.0
# 31266271232.0
# 34841268224.0
# 38604976128.0
# 42556694528.0
# 46695645184.0
# 51021443072.0
# 55532933120.0
# 60229697536.0
# 65110884352.0
# 70175899648.0
# 75423948800.0
# 80854474752.0
# 86466527232.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-4473ffb96637> in <module>
#       5         print(loss.item())
#       6     loss.backward()
# ----> 7     optimizer.step()
#
# ~/miniconda3/envs/torch-dev/lib/python3.8/site-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      85                 obj, *_ = args
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
# ---> 87                 with torch.autograd.profiler.record_function(profile_name):
#      88                     return func(*args, **kwargs)
#      89             return wrapper
#
# ~/miniconda3/envs/torch-dev/lib/python3.8/site-packages/torch/autograd/profiler.py in __enter__(self)
#     614
#     615     def __enter__(self):
# --> 616         self.handle = torch.ops.profiler._record_function_enter(self.name)
#     617         return self
#     618
#
# KeyboardInterrupt:

# %%
index=6
print(output.detach().numpy()[index].shape)
print(output.detach().numpy()[index])
plt.imshow(output.detach().numpy()[index])
plt.show()
plt.imshow(VideoTrain.detach().numpy()[index])
plt.show()
print(VideoTrain.detach().numpy()[index])
# Out:
# (64, 64)
# [[-1513335.  -1513335.  -1513335.  ... -1513335.  -1513335.  -1513335. ]
#  [-1513335.  -1513335.  -1513335.  ... -1513335.  -1513335.  -1513335. ]
#  [-1513335.  -1513335.  -1513335.  ... -1513335.  -1513335.  -1513335. ]
#  ...
#  [-1513335.4 -1513335.4 -1513335.4 ... -1513335.4 -1513335.4 -1513335.4]
#  [-1513335.4 -1513335.4 -1513335.4 ... -1513335.4 -1513335.4 -1513335.4]
#  [-1513335.4 -1513335.4 -1513335.4 ... -1513335.4 -1513335.4 -1513335.4]]
# [[255. 255. 255. ... 255. 255. 255.]
#  [255. 255. 255. ... 255. 255. 255.]
#  [255. 255. 255. ... 255. 255. 255.]
#  ...
#  [255. 255. 255. ... 255. 255. 255.]
#  [255. 255. 255. ... 255. 255. 255.]
#  [255. 255. 255. ... 255. 255. 255.]]

# %%
print(list(rnn.parameters())[1].shape)
# Out:
# torch.Size([67, 64, 64])

# %%
height = 64
width = 64
fourcc = VideoWriter_fourcc(*'MP42')
video = VideoWriter('./data/project.avi', fourcc, float(24), (width, height))

print(len(output))
for i in range(len(output)):
    
    video.write(cv2.cvtColor((output[i].detach().numpy()*255).astype(np.uint8),cv2.COLOR_GRAY2BGR))
video.release()
# Out:
# 66

# %%
print(optimizer.param_groups[0]['params'][2].shape)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-92-5a51f4871016> in <module>
# ----> 1 print(optimizer.param_groups[0]['params'][2].shape)
#
# IndexError: list index out of range
